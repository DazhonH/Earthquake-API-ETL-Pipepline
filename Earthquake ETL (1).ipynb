# %%
import requests
import pandas as pd
from datetime import date, timedelta
import json

# %%
start_date = date.today() - timedelta(7)
end_date = date.today() - timedelta(1)

url = f"https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime={start_date}&endtime={end_date}"

print(url)
# Out:
# https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2025-02-07&endtime=2025-02-13

# %%
# USGS Earthquake API URL
url = f"https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime={start_date}&endtime={end_date}"

# Extracting from API
response = requests.get(url)

# Checking status code
if response.status_code == 200:
    data = response.json()
    print("API fetch successfull")
else:
    print("Error fetching json data")

print(data)
# Out:
# API fetch successfull
# {'type': 'FeatureCollection', 'metadata': {'generated': 1739560445000, 'url': 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2025-02-07&endtime=2025-02-13', 'title': 'USGS Earthquakes', 'status': 200, 'api': '1.14.1', 'count': 1858}, 'features': [{'type': 'Feature', 'properties': {'mag': 2.7, 'place': '34 km SE of Malaga, New Mexico', 'time': 1739404758069, 'updated': 1739406380640, 'tz': None, 'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2025daop', 'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=tx2025daop&format=geojson', 'felt': None, 'cdi': None, 'mmi': None, 'alert': None, 'status': 'reviewed', 'tsunami': 0, 'sig': 112, 'net': 'tx', 'code': '2025daop', 'ids': ',tx2025daoo,us7000pda6,tx2025daop,', 'sources': ',tx,us,tx,', 'types': ',origin,phase-data,', 'nst': 33, 'dmin': 0, 'rms': 0.1, 'gap': 28, 'magType': 'ml', 'type': 'earthquake', 'title': 'M 2.7 - 34 km SE of Malaga, New Mexico'}, 'geometry': {'type': 'Point', 'coordinates': [-103.805, 32.007, 7.0868]}, 'id': 'tx2025daop'}, {'type': 'Feature', 'properties': {'mag': 1.9, 'place': '30 km NW of Willow, Alaska', 'time': 1739404710361, 'updated': 1739404833785, 'tz': None, 'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0251zi5e0s', 'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak0251zi5e0s&format=geojson', 'felt': None, 'cdi': None, 'mmi': None, 'alert': None, 'status': 'automatic', 'tsunami': 0, 'sig': 56, 'net': 'ak', 'code': '0251zi5e0s', 'ids': ',ak0251zi5e0s,', 'sources': ',ak,', 'types': ',origin,phase-data,', 'nst': None, 'dmin': None, 'rms': 0.48, 'gap': None, 'magType': 'ml', 'type': 'earthquake', 'title': 'M 1.9 - 30 km NW of Willow, Alaska'}, 'geometry': {'type': 'Point', 'coordinates': [-150.4411, 61.9425, 29.4]}, 'id': 'ak0251zi5e0s'}, {'type': 'Feature', 'properties': {'mag': 0.3, 'place': '59 km W of Tyonek, Alaska', 'time': 1739403954105, 'updated': 1739407096160, 'tz': None, 'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0251zi2nmi', 'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak0251zi2nmi&format=geojson', 'felt': None, 'cdi': None, 'mmi': None, 'alert': None, 'status': 'automatic', 'tsunami': 0, 'sig': 1, 'net': 'ak', 'code': '0251zi2nmi', 'ids': ',av93498056,ak0251zi2nmi,', 'sources': ',av,ak,', 'types': ',origin,phase-data,', 'nst': None, 'dmin': None, 'rms': 0.54, 'gap': None, 'magType': 'ml', 'type': 'earthquake', 'title': 'M 0.3 - 59 km W of Tyonek, Alaska'}, 'geometry': {'type': 'Point', 'coordinates': [-152.2285, 61.1445, 15.8]}, 'id': 'ak0251zi2nmi'}, {'type': 'Feature', 'properties': {'mag': 0.48, 'place': '24 km SSW of New Idria, CA', 'time': 1739403815250, 'updated': 1739403911992, 'tz': None, 'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75132492', 'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75132492&format=geojson', 'felt': None, 'cdi': None, 'mmi': None, 'alert': None, 'status': 'automatic', 'tsunami': 0, 'sig': 4, 'net': 'nc', 'code': '75132492', 'ids': ',nc75132492,', 'sources': ',nc,', 'types': ',nearby-cities,origin,phase-data,', 'nst': 7, 'dmin': 0.0777, 'rms': 0.11, 'gap': 221, 'magType': 'md', 'type': 'earthquake', 'title': 'M 0.5 - 24 km SSW of New Idria, CA'}, 'geometry': {'type': 'Point', 'coordinates': [-120.705833435059, 36.2068328857422, 9.64000034332275]}, 'id': 'nc75132492'}, {'type': 'Feature', 'properties': {'mag': 1.9, 'place': '38 km N of Chase, Alaska', 'time': 1739403810057, 'updated': 1739403956266, 'tz': None, 'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0251zi268z', 'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak0251zi268z&format=geojson', 'felt': None, 'cdi': None, 'mmi': None, 'alert': None, 'status': 'automatic', 'tsunami': 0, 'sig': 56, 'net': 'ak', 'code': '0251zi268z', 'ids': ',ak0251zi268z,', 'sources': ',ak,', 'types': ',origin,phase-data,', 'nst': None, 'dmin': None, 'rms': 0.47, 'gap': None, 'magTy ...

# %%
data_raw = pd.json_normalize(data['features'])
data_raw
# Out:
#          type            id  properties.mag                  properties.place  \
# 0     Feature    tx2025daop            2.70    34 km SE of Malaga, New Mexico
# 1     Feature  ak0251zi5e0s            1.90        30 km NW of Willow, Alaska
# 2     Feature  ak0251zi2nmi            0.30         59 km W of Tyonek, Alaska
# 3     Feature    nc75132492            0.48        24 km SSW of New Idria, CA
# 4     Feature  ak0251zi268z            1.90          38 km N of Chase, Alaska
# ...       ...           ...             ...                               ...
# 1853  Feature    uw62066027            0.15  22 km ENE of Ashford, Washington
# 1854  Feature  ak0251quhu1f            1.40         94 km N of Karluk, Alaska
# 1855  Feature    ci40181162            1.85         12 km SE of Tehachapi, CA
# 1856  Feature  ak0251qugrut            1.80  59 km E of Port Alsworth, Alaska
# 1857  Feature  ak0251qufmt4            1.40            11 km E of Fox, Alaska
#
#       properties.time  properties.updated properties.tz  \
# 0       1739404758069       1739406380640          None
# 1       1739404710361       1739404833785          None
# 2       1739403954105       1739407096160          None
# 3       1739403815250       1739403911992          None
# 4       1739403810057       1739403956266          None
# ...               ...                 ...           ...
# 1853    1738887407640       1739392500710          None
# 1854    1738887154756       1738957956620          None
# 1855    1738886902020       1738951984410          None
# 1856    1738886859930       1738968119040          None
# 1857    1738886527928       1738886640219          None
#
#                                          properties.url  \
# 0     https://earthquake.usgs.gov/earthquakes/eventp...
# 1     https://earthquake.usgs.gov/earthquakes/eventp...
# 2     https://earthquake.usgs.gov/earthquakes/eventp...
# 3     https://earthquake.usgs.gov/earthquakes/eventp...
# 4     https://earthquake.usgs.gov/earthquakes/eventp...
# ...                                                 ...
# 1853  https://earthquake.usgs.gov/earthquakes/eventp...
# 1854  https://earthquake.usgs.gov/earthquakes/eventp...
# 1855  https://earthquake.usgs.gov/earthquakes/eventp...
# 1856  https://earthquake.usgs.gov/earthquakes/eventp...
# 1857  https://earthquake.usgs.gov/earthquakes/eventp...
#
#                                       properties.detail  properties.felt  ...  \
# 0     https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
# 1     https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
# 2     https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
# 3     https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
# 4     https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
# ...                                                 ...              ...  ...
# 1853  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
# 1854  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
# 1855  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
# 1856  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
# 1857  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
#
#                                        properties.types  properties.nst  \
# 0                                   ,origin,phase-data,            33.0
# 1                                   ,origin,phase-data,             NaN
# 2                                   ,origin,phase-data,             NaN
# 3                     ,nearby-cities,origin,phase-data,             7.0
# 4                                   ,origin,phase-data,             NaN
# ...                                                 ...             ...
# 1853                                ,origin,phase-data,            18.0
# 1854                                ,origin,phase-data,             NaN
# 1855  ,focal-mechanism,nearby-cities,origin,phase-da...            36.0
# 1856                                ,origin,phase-data,             NaN
# 1857                                ,origin,phase-data,             NaN
#
#      properties.dmin properties.rms  properties.gap  properties.magType  \
# 0            0.00000           0.10            28.0                  ml
# 1                NaN           0.48             NaN                  ml
# 2                NaN           0.54             NaN                  ml
# 3            0.07770           0.11           221.0                  md
# 4                NaN           0.47             NaN                  ml
# ...              ...            ...             ...                 ...
# 1853         0.01898           0.08            70.0                  ml
# 1854             NaN           0.52             NaN                  ml
# 1855         0.07331           0.15            38.0                  ml
# 1856             NaN           0.28             NaN                  ml
# 1857             NaN           0.34             NaN                  ml
#
#      properties.type                          properties.title geometry.type  \
# 0         earthquake    M 2.7 - 34 km SE of Malaga, New Mexico         Point
# 1         earthquake        M 1.9 - 30 km NW of Willow, Alaska         Point
# 2         earthquake         M 0.3 - 59 km W of Tyonek, Alaska         Point
# 3         earthquake        M 0.5 - 24 km SSW of New Idria, CA         Point
# 4         earthquake          M 1.9 - 38 km N of Chase, Alaska         Point
# ...              ...                                       ...           ...
# 1853      earthquake  M 0.2 - 22 km ENE of Ashford, Washington         Point
# 1854      earthquake         M 1.4 - 94 km N of Karluk, Alaska         Point
# 1855      earthquake         M 1.9 - 12 km SE of Tehachapi, CA         Point
# 1856      earthquake  M 1.8 - 59 km E of Port Alsworth, Alaska         Point
# 1857      earthquake            M 1.4 - 11 km E of Fox, Alaska         Point
#
#                                    geometry.coordinates
# 0                            [-103.805, 32.007, 7.0868]
# 1                            [-150.4411, 61.9425, 29.4]
# 2                            [-152.2285, 61.1445, 15.8]
# 3     [-120.705833435059, 36.2068328857422, 9.640000...
# 4                            [-149.9799, 62.7895, 74.9]
# ...                                                 ...
# 1853     [-121.76533333333333, 46.85183333333333, 1.75]
# 1854                          [-154.6902, 58.4053, 5.6]
# 1855                   [-118.3488333, 35.0638333, 4.69]
# 1856                         [-153.241, 60.1802, 150.8]
# 1857                          [-147.3715, 64.9709, 2.5]
#
# [1858 rows x 30 columns]

# %% [markdown]
# ## Transformation

# %%
# 1. Drop Unwanted Columns
# 2. Convert properties.time and updated into date time
# 3. Split Coordinates
# 4. Concat coordinates and cleaned df
# 5.Strip Propoerties.types
# 6. Drop Duplicates
# 7. Reorder columns

# %%
#1 Drop Unwanted Columns

data_cleaned = data_raw.drop(columns = ['properties.detail','properties.url','properties.tz', 
                                    'properties.felt','properties.nst','properties.gap',
                                    'properties.dmin','geometry.type','properties.cdi',
                                    'properties.mmi','properties.alert','properties.status',
                                    'properties.net','properties.code','properties.ids',
                                     'properties.sources','properties.tsunami','properties.types',
                                    'properties.rms','properties.type'
                                    ])

# %%
data_cleaned.head(5)
# Out:
#       type            id  properties.mag                properties.place  \
# 0  Feature    tx2025daop            2.70  34 km SE of Malaga, New Mexico
# 1  Feature  ak0251zi5e0s            1.90      30 km NW of Willow, Alaska
# 2  Feature  ak0251zi2nmi            0.30       59 km W of Tyonek, Alaska
# 3  Feature    nc75132492            0.48      24 km SSW of New Idria, CA
# 4  Feature  ak0251zi268z            1.90        38 km N of Chase, Alaska
#
#    properties.time  properties.updated  properties.sig properties.magType  \
# 0    1739404758069       1739406380640             112                 ml
# 1    1739404710361       1739404833785              56                 ml
# 2    1739403954105       1739407096160               1                 ml
# 3    1739403815250       1739403911992               4                 md
# 4    1739403810057       1739403956266              56                 ml
#
#                          properties.title  \
# 0  M 2.7 - 34 km SE of Malaga, New Mexico
# 1      M 1.9 - 30 km NW of Willow, Alaska
# 2       M 0.3 - 59 km W of Tyonek, Alaska
# 3      M 0.5 - 24 km SSW of New Idria, CA
# 4        M 1.9 - 38 km N of Chase, Alaska
#
#                                 geometry.coordinates
# 0                         [-103.805, 32.007, 7.0868]
# 1                         [-150.4411, 61.9425, 29.4]
# 2                         [-152.2285, 61.1445, 15.8]
# 3  [-120.705833435059, 36.2068328857422, 9.640000...
# 4                         [-149.9799, 62.7895, 74.9]

# %%
# Dividing y 1000 to convert into seconds
data_cleaned['properties.time'] = data_cleaned['properties.time'] / 1000
data_cleaned['properties.updated'] = data_cleaned['properties.updated'] / 1000

# Converting the columns into datetime
data_cleaned['properties.time'] = pd.to_datetime(data_cleaned['properties.time'],unit = 's')
data_cleaned['properties.updated'] = pd.to_datetime(data_cleaned['properties.updated'],unit = 's')

# %%
data_cleaned.head(5)
# Out:
#       type            id  properties.mag                properties.place  \
# 0  Feature    tx2025daop            2.70  34 km SE of Malaga, New Mexico
# 1  Feature  ak0251zi5e0s            1.90      30 km NW of Willow, Alaska
# 2  Feature  ak0251zi2nmi            0.30       59 km W of Tyonek, Alaska
# 3  Feature    nc75132492            0.48      24 km SSW of New Idria, CA
# 4  Feature  ak0251zi268z            1.90        38 km N of Chase, Alaska
#
#                 properties.time            properties.updated  properties.sig  \
# 0 2025-02-12 23:59:18.069000006 2025-02-13 00:26:20.640000105             112
# 1 2025-02-12 23:58:30.361000061 2025-02-13 00:00:33.785000086              56
# 2 2025-02-12 23:45:54.105000019 2025-02-13 00:38:16.160000086               1
# 3 2025-02-12 23:43:35.250000000 2025-02-12 23:45:11.992000103               4
# 4 2025-02-12 23:43:30.056999922 2025-02-12 23:45:56.266000032              56
#
#   properties.magType                        properties.title  \
# 0                 ml  M 2.7 - 34 km SE of Malaga, New Mexico
# 1                 ml      M 1.9 - 30 km NW of Willow, Alaska
# 2                 ml       M 0.3 - 59 km W of Tyonek, Alaska
# 3                 md      M 0.5 - 24 km SSW of New Idria, CA
# 4                 ml        M 1.9 - 38 km N of Chase, Alaska
#
#                                 geometry.coordinates
# 0                         [-103.805, 32.007, 7.0868]
# 1                         [-150.4411, 61.9425, 29.4]
# 2                         [-152.2285, 61.1445, 15.8]
# 3  [-120.705833435059, 36.2068328857422, 9.640000...
# 4                         [-149.9799, 62.7895, 74.9]

# %%
data_cleaned[['Longitude', 'Latitude', 'Elevation']] = pd.DataFrame(data_cleaned['geometry.coordinates'].to_list(), index=data_cleaned.index)
data_cleaned = data_cleaned.drop(columns =['geometry.coordinates'])

# %%
data_cleaned.head(5)
# Out:
#       type            id  properties.mag                properties.place  \
# 0  Feature    tx2025daop            2.70  34 km SE of Malaga, New Mexico
# 1  Feature  ak0251zi5e0s            1.90      30 km NW of Willow, Alaska
# 2  Feature  ak0251zi2nmi            0.30       59 km W of Tyonek, Alaska
# 3  Feature    nc75132492            0.48      24 km SSW of New Idria, CA
# 4  Feature  ak0251zi268z            1.90        38 km N of Chase, Alaska
#
#                 properties.time            properties.updated  properties.sig  \
# 0 2025-02-12 23:59:18.069000006 2025-02-13 00:26:20.640000105             112
# 1 2025-02-12 23:58:30.361000061 2025-02-13 00:00:33.785000086              56
# 2 2025-02-12 23:45:54.105000019 2025-02-13 00:38:16.160000086               1
# 3 2025-02-12 23:43:35.250000000 2025-02-12 23:45:11.992000103               4
# 4 2025-02-12 23:43:30.056999922 2025-02-12 23:45:56.266000032              56
#
#   properties.magType                        properties.title   Longitude  \
# 0                 ml  M 2.7 - 34 km SE of Malaga, New Mexico -103.805000
# 1                 ml      M 1.9 - 30 km NW of Willow, Alaska -150.441100
# 2                 ml       M 0.3 - 59 km W of Tyonek, Alaska -152.228500
# 3                 md      M 0.5 - 24 km SSW of New Idria, CA -120.705833
# 4                 ml        M 1.9 - 38 km N of Chase, Alaska -149.979900
#
#     Latitude  Elevation
# 0  32.007000     7.0868
# 1  61.942500    29.4000
# 2  61.144500    15.8000
# 3  36.206833     9.6400
# 4  62.789500    74.9000

# %%
data_cleaned = data_cleaned.rename(columns={'properties.mag':'mag',
                             'properties.place':'place',
                             'properties.time':'time',
                            'properties.updated':'updated',
                             'properties.sig':'sig',
                             'properties.magType':'magType',
                            'properties.title':'title'})
data_cleaned.head(5)
# Out:
#       type            id   mag                           place  \
# 0  Feature    tx2025daop  2.70  34 km SE of Malaga, New Mexico
# 1  Feature  ak0251zi5e0s  1.90      30 km NW of Willow, Alaska
# 2  Feature  ak0251zi2nmi  0.30       59 km W of Tyonek, Alaska
# 3  Feature    nc75132492  0.48      24 km SSW of New Idria, CA
# 4  Feature  ak0251zi268z  1.90        38 km N of Chase, Alaska
#
#                            time                       updated  sig magType  \
# 0 2025-02-12 23:59:18.069000006 2025-02-13 00:26:20.640000105  112      ml
# 1 2025-02-12 23:58:30.361000061 2025-02-13 00:00:33.785000086   56      ml
# 2 2025-02-12 23:45:54.105000019 2025-02-13 00:38:16.160000086    1      ml
# 3 2025-02-12 23:43:35.250000000 2025-02-12 23:45:11.992000103    4      md
# 4 2025-02-12 23:43:30.056999922 2025-02-12 23:45:56.266000032   56      ml
#
#                                     title   Longitude   Latitude  Elevation
# 0  M 2.7 - 34 km SE of Malaga, New Mexico -103.805000  32.007000     7.0868
# 1      M 1.9 - 30 km NW of Willow, Alaska -150.441100  61.942500    29.4000
# 2       M 0.3 - 59 km W of Tyonek, Alaska -152.228500  61.144500    15.8000
# 3      M 0.5 - 24 km SSW of New Idria, CA -120.705833  36.206833     9.6400
# 4        M 1.9 - 38 km N of Chase, Alaska -149.979900  62.789500    74.9000

# %%
#Defining Sig Class

def sig_class:
    if sig_class < 100:
        return 'low'
elif sig_class >= 100
